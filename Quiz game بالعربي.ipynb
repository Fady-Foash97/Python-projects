# %%
import random
def Quiz():
    while True:
     print("استعد للعب: ")
     score = 0
     failed = 0
     
     ## السؤال 1:
     print("\nالسؤال 1: ما هو أطول نهر في العالم؟")
     options1 = ["نهر الأمازون", "نهر النيل", "نهر الأردن", "نهر دجلة و الفرات"]
     random.shuffle(options1)
     print(", ".join(options1))
     answer1 = input("اختار الاجابة الصحيحة: ")
     if answer1 == "نهر النيل":
         print("اجابة صحيحة, نهر النيل هو أطول نهر في العالم و يعتبر شريان الحياة لمصر")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     elif answer1 == "نهر الأمازون":
         print("غير صحيح, نهر الأمازون هو ثاني أكبر نهر في العالم و لديه عدة شبكات مياه و منابع")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 2:
     print("\nالسؤال 2: ما هي الدولة التي تعرف بأنها: أرض الجليد و النار")
     options2 = ["السويد", "روسيا", "النرويج", "أيسلندا"]
     random.shuffle(options2)
     print(", ".join(options2))
     answer2 = input("اختار الاجابة الصحيحة: ")
     if answer2 == "أيسلندا":
         print("اجابة صحيحة, أيسلندا معروفة بهذا اللقب بسبب نشاطها البركاني و طبيعتها الجليدية")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 3:
     print("\nالسؤال 3: ما هو الكوكب الذي يحيط به حلقات؟")
     options3 = ["الأرض", "زحل", "عطارد", "المريخ"]
     random.shuffle(options3)
     print(", ".join(options3))
     answer3 = input("اختار الاجابة الصحيحة: ")
     if answer3 == "زحل":
         print("اجابة صحيحة, زحل هو الكوكب الذي يحيط به حلقات")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 4:
     print("\nالسؤال 4: ما هو أكبر محيط في العالم")
     options4 = ["المحيط الأطلنطي", "المحيط الهادي", "المحيط الهندي", "المحيط القطبي"]
     random.shuffle(options4)
     print(", ".join(options4))
     answer4 = input("اختار الاجابة الصحيحة: ")
     if answer4 == "المحيط الهادي":
         print("اجابة صحيحة, المحيط الهادي هو أكبر محيط في العالم, يفصل ما بين القارة الأمريكية و قارة أسيا و أستراليا")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")  
         
     ## السؤال 5:
     print("\nالسؤال 5: ما هو الحيوان المعروف بالنشاط؟")
     options5 = ["النمل", "النحل", "الدولفين", "السنجاب"]
     random.shuffle(options5)
     print(", ".join(options5))
     answer5 = input("اختار الاجابة الصحيحة: ")
     if answer5 == "النمل":
         print("اجابة صحيحة, النمل معروف بنشاطه الدائم")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 6:
     print("\n السؤال 6: ما هي العملة الرسمية لروسيا؟")
     options6 = ["اليورو", "الروبي", "الروبل", "الدينار"]
     random.shuffle(options6)
     print(", ".join(options6))
     answer6 = input("اختار الاجابة الصحيحة: ")
     if answer6 == "الروبل":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
         
     ## السؤال 7:
     print("\nالسؤال 7: أين صنع تمثال الحرية")
     options7 = ["الولايات المتحدة", "فرنسا", "ايطاليا", "أسبانيا"]
     print(", ".join(options7))
     answer7 = input("اختار الاجابة الصحيحة: ")
     if answer7 == "فرنسا":
         print("اجابة صحيحة, تمثال الحرية تم صنعه في فرنسا و تم ارساله الي الولايات المتحدة كهدية سنة 1886")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     elif answer7 == "الولايات المتحدة":
         print("غير صحيح, التمثال لم يتم صنعه في الولايات المتحدة")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     else: 
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 8:
     print("\nالسؤال 8:  أين يوجد مقر شركة  السيارات الكهربائية BYD?")
     options8 = ["ألمانيا", "اليابان", "الصين", "الولايات المتحدة"]
     print(", ".join(options8))
     answer8 = input("اختار الاجابة الصحيحة: ")
     if answer8 == "الصين":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
         
     ## السؤال 9:
     print("\n السؤال 9: أين أقيمت الألعاب الأولومبية لأول مرة؟")
     answer9 = input(" ")
     if answer9 == "اليونان":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 10:
     print("\n السؤال 10: ما هي عاصمة أثيوبيا؟")
     answer10 = input(" ")
     if answer10 == "أديس أبابا":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 11:
     print("\n السؤال 11: ما هو أخر كوكب في المجموعة الشمسية؟")
     answer11 = input(" ")
     if answer11 == "بلوتو":
         print("اجابة صحيحة, كوكب بلوتو هو أخر كوكب في المجموعة الشمسية")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 12:
     print("\n السؤال 12: من هو مؤسس الاقتصاد الحديث؟")
     answer12 = input("")
     if answer12 == "أدم سميث":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 13:
     print("\n السؤال 13: من هو مؤسس مدينة القاهرة في مصر؟")
     answer13 = input("")
     if answer13 == "الخليفة المعز":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 14:
     print("\n السؤال 14: ما هي أكبر دولة في العالم؟")
     options9 = ["روسيا", "كندا", "الصين", "الولايات المتحدة"]
     random.shuffle(options9)
     print(", ".join(options9))
     answer14 = input("اختار الاجابة الصحيحة: ")
     if answer14 == "روسيا":
         print("اجابة صحيحة.")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 15:
     print("\n السؤال 15: من هو قائد الحملة الصليبية الثالثة؟")
     options10 = ["ريتشارد قلب الأسد", "لويس التاسع", "باربروسا", "جون"]
     random.shuffle(options10)
     print(", ".join(options10))
     answer15 = input("اختار الاجابة الصحيحة: ")
     if answer15 == "ريتشارد قلب الأسد":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 16:
     print("\n السؤال 16: ما هو الطائر الذي لا يطير؟")
     answer16 = input("")
     if answer16 == "البطريق":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 17:
     print("\n السؤال 17: من هو الرئيس الأمريكي الذي تصدي للكساد العظيم الذي حدث في 1929؟")
     options11 = ["هاري ترومان", "وودرو ويلسون", "دوايت ايزنهاور", "فرانكلين روزفلت"]
     random.shuffle(options11)
     print(", ".join(options11))
     answer17 = input("اختار الاجابة الصحيحة: ")
     if answer17 == "فرانكلين روزفلت":
         print("اجابة صحيحة, فرانكلين روزفلت تولي الحكم من  1933 حتي وفاته في 12 أبريل 1945 في نهاية الحرب العالمية الثانية")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     elif answer17 == "هاري ترومان":
         print("غير صحيح, هاري ترومان تولي الحكم من 12 أبريل 1945 حتي 20 يناير 1953, في عهده أطلق القنبلة النووية علي اليابان")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     elif answer17 == "وودرو ويلسون":
         print("غير صحيح, وودرو ويلسون تولي الحكم من 1913 الي 1921, في عهده دخلت أمريكا الحرب العالمية الأولي و تأسست مؤسسة عصبة الأمم")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     elif answer17 == "دوايت ايزنهاور":
         print("غير صحيح, ايزنهاور تولي الحكم في فترة خمسينات القرن الماضي")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 18:
     print("\n السؤال 18: ما هو الطعام الذي لا يفسد؟")
     answer18 = input("")
     if answer18 == "العسل":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 19:
     print("\n السؤال 19: ما هو الكوكب المسمي بالكوكب الأحمر؟")
     answer19 = input("")
     if answer19 == "المريخ":
         print("اجابة صحيحة, في اللغة الانجليزية اسم الكوكب هو Mars نسبة الي اله الحرب الروماني بنفس الاسم, و هذا سبب شهرته بالكوكب الأحمر")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     ## السؤال 20:
     print("\n السؤال 20: ما هي شركة التكنولوجيا الأكبر في العالم؟")
     options12 = ["أبل", "نفيديا", "تسلا", "جوجل"]
     random.shuffle(options12)
     answer20 = input("اختار الاجابة الصحيحة: ")
     if answer20 == "أبل":
         print("اجابة صحيحة")
         score += 1
         print(f"حصلت علي {score} نقطة من 20 نقطة")
     else:
         print("غير صحيح")
         failed += 1
         print(f"خسرت {failed} نقطة من 20 نقطة")
     
     print("\n انتهت اللعبة!")
     print(f"حصلت علي{score} نقطة من 20 نقطة")
     if score == 20:
         print("ممتاز!")
     elif score >= 15:
         print("أحسنت!")
     elif score >= 7:
         print("جيد جدا")
     else:
         print("حظ سعيد")
     play = input("أتريد اللعب مرة أخري (نعم\لا)")
     if play != "نعم":
         print("شكرا للعبك لعبتنا!")
         break
Quiz()
